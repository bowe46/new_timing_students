# %% [markdown]
# Calculations for exerxises

# %%
import astropy.constants as cons
import astropy.units as u
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
L = 4 * np.pi * cons.sigma_sb * (2 * u.keV / cons.k_B)**4 * (10. * u.km)**2
L.cgs
# Out:
# <Quantity 2.06752147e+38 erg / s>

# %%
L_edd = 1.3e38 * 1.4 * u.erg / u.s
L_edd
# Out:
# <Quantity 1.82e+38 erg / s>

# %%
def b(e, kt):
    return ( 2 *np.pi * (e * u.keV)**3 / (cons.h * cons.c)**2 * 1/ ( np.exp (e/kt ) -1 ) ).cgs.value

# %%
e=10**np.linspace(-1.,2., 100)
kt =2.
spec=b(e,kt)

# %%
plt.figure()
plt.loglog(e,(spec))
plt.xlabel('Energy [keV]')
plt.ylabel('B(E,kT=%.1f keV) [g/s^2]'%kt)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'B(E,kT=2.0 keV) [g/s^2]')

# %%
import scipy.integrate as integrate

low=0.1
high=10.0
result = integrate.quad(lambda x: b(x,kt), low,high) 
lumin= result[0] * (u.keV/cons.h).cgs.value * 4* np.pi * ((10 * u.km).cgs.value)**2

print('L(%.1f-%.1f) = %.2g erg/s'%(low,high, lumin))
# Out:
# L(0.1-10.0) = 1.6e+38 erg/s

# %%
low=0.1
high=20.0
result = integrate.quad(lambda x: b(x,kt), low,high)
lumin= result[0] * (u.keV/cons.h).cgs.value * 4* np.pi * ((10 * u.km).cgs.value)**2

print('L(%.1f-%.1f) = %.2g erg/s'%(low,high, lumin))
# Out:
# L(0.1-20.0) = 2e+38 erg/s

# %%
# Show the narrow band of a BB
attempt=[b(0.5,kt), b(3*kt,kt), b(20,kt)]
print(attempt/attempt[1])
# Out:
# [0.03888691 1.         0.03209338]

# %%
zp1 = (1- 2 * 1.4*cons.GM_sun / (10 *u.km)/ cons.c**2)**(-0.5)
zp1
# Out:
# <Quantity 1.30571783>

# %%
R=10 * u.km
H=1e2 * u.cm
rho = 1e6 *u.g / u.cm**3
M= 1.4 * cons.M_sun
Q = 7 * u.MeV
e_release = 4 * np.pi * R**2 *H * rho / cons.m_p * Q 
e_release.cgs
# Out:
# <Quantity 8.42598172e+39 erg>

# %%
Q = 1.5 * u.MeV
e_release = 4 * np.pi * R**2 *H * rho / cons.m_p * Q 
e_release.cgs
# Out:
# <Quantity 1.80556751e+39 erg>

# %%
ratio = Q * R /cons.G / M / cons.m_p
1/ratio.cgs
# Out:
# <Quantity 129.31109874>

# %%
B=np.array([1, 5e-4]) #in units of 1e12 G
r_m=1800 * B**(4./7.)
print(np.sqrt(np.arcsin(10./r_m)) * 180/np.pi)
# Out:
# [ 4.27058624 38.08459305]

# %%
1e-4**(4./7.)*1800
# Out:
# 9.323054422616183

# %%
dir(cons)
# Out:
# ['Constant',
#  'EMConstant',
#  'G',
#  'GM_earth',
#  'GM_jup',
#  'GM_sun',
#  'L_bol0',
#  'L_sun',
#  'M_earth',
#  'M_jup',
#  'M_sun',
#  'N_A',
#  'R',
#  'R_earth',
#  'R_jup',
#  'R_sun',
#  'Ryd',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'a0',
#  'alpha',
#  'atm',
#  'au',
#  'b_wien',
#  'c',
#  'cgs',
#  'codata',
#  'codata2018',
#  'config',
#  'constant',
#  'e',
#  'eps0',
#  'g0',
#  'h',
#  'hbar',
#  'iau2015',
#  'iaudata',
#  'k_B',
#  'kpc',
#  'm_e',
#  'm_n',
#  'm_p',
#  'mu0',
#  'muB',
#  'pc',
#  'set_enabled_constants',
#  'si',
#  'sigma_T',
#  'sigma_sb',
#  'u',
#  'utils']
